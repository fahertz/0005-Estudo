# %% [markdown]
# # Projeto: Ligações para o 911

# %% [markdown]
# Para este projeto estaremos analisando alguns dados de chamadas para o 911 do [Kaggle](https://www.kaggle.com/mchirico/montcoalert). Os dados contém os seguintes campos:
#
# * lat: Variável String, Latitude
# * lng: Variável String, Longitude
# * desc: Variável String, Descrição da Chamada de Emergência
# * zip: Variável String, CEP
# * título: Variável String, Título
# * timeStamp: Variável String, AAAA-MM-DD HH: MM: SS
# * twp: Variável String, Township
# * addr: Variável String, Endereço
# * e: Variável String, variável Dummy (sempre 1)
#
# Simplesmente acompanhe este notebook e tente completar as instruções ou responder as perguntas em negrito usando suas habilidades Python e Data Science!

# %% [markdown]
# ## Dados e Configuração

# %% [markdown]
# ** Importar numpy e pandas **

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ** Importe as bibliotecas de visualização e configure% matplotlib inline. **

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ** Leia o arquivo csv como um dataframe chamado df **

# %%
ocurrences = pd.read_csv(r"C:\Users\rafael.silva\Documents\005-Estudo\4. Projetos de dados\911.csv")

# %% [markdown]
# ** Verifique a info() do df **

# %%
ocurrences.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %% [markdown]
# ** Verifique o cabeçalho do df **

# %%
ocurrences.head(2)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1

# %% [markdown]
# ## Perguntas básicas

# %% [markdown]
# ** Quais são os top 5 CEPs nas chamadas 911? **

# %%
ocurrences["zip"].value_counts().iloc[0:5]
# Out:
# zip
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: count, dtype: int64

# %% [markdown]
# ** Quais são os 5 principais municípios nas chamadas 911? **

# %%
ocurrences["twp"].value_counts().iloc[0:5]
# Out:
# twp
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: count, dtype: int64

# %% [markdown]
# ** Dê uma olhada na coluna 'title'. Quantos códigos de título exclusivos existem? **

# %%
ocurrences["title"].nunique()
# Out:
# 110

# %% [markdown]
# ## Criando novos recursos

# %% [markdown]
# ** Na coluna "title" existem "Razões / Departamentos" especificados antes do código do título. Estes são "EMS", "Fire" e "Traffic". Use .apply () com uma expressão lambda personalizada para criar uma nova coluna chamada "Razão" que contém esse valor de string. **
#
# ** Por exemplo, se o valor da coluna do título for EMS: BACK PAINS / BLESSOR, o valor da coluna Reason seria EMS. **

# %%
ocurrences["Reason"] = ocurrences["title"].apply(lambda ocTitle: ocTitle.split(':')[0])

# %% [markdown]
# ** Qual é o motivo mais comum para uma chamada do 911 com base nessa nova coluna? **

# %%
ocurrences["Reason"].value_counts()
# Out:
# Reason
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: count, dtype: int64

# %% [markdown]
# ** Agora use Seaborn para criar um countplot de chamadas 911 baseadas nesta nova coluna. **

# %%
sns.countplot(ocurrences,x="Reason", palette= "tab10")
# Out:
# <Axes: xlabel='Reason', ylabel='count'>

# %% [markdown]
# ** Agora vamos começar a focar em informações de tempo. Qual é o tipo de dados dos objetos na coluna timeStamp? **

# %%
type(ocurrences["timeStamp"].iloc[0])
# Out:
# str

# %% [markdown]
# ** Você deveria ter notado que esses timestamps ainda são strings. Use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) para converter a coluna de strings em objetos DateTime. **

# %%
ocurrences["timeStamp"] = pd.to_datetime(ocurrences["timeStamp"])
type(ocurrences["timeStamp"].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ** Agora você pode pegar atributos específicos de um objeto Datetime chamando-os. Por exemplo:**
#
#     time = df['timeStamp'].iloc[0]
#     time.hour
#
# ** Você pode usar o método de consulta de funções do Jupyter (Tab) para explorar os vários atributos que você pode chamar. Agora que a coluna timestamp é realmente objetos DateTime, use .apply () para criar 3 novas colunas chamadas Hour, Month e Day of Week. Você criará essas colunas com base na coluna timeStamp, consulte as soluções se você ficar preso nesta etapa. **

# %%
ocurrences["Hour"]= ocurrences["timeStamp"].apply(lambda ts: ts.hour)
ocurrences["Month"]= ocurrences["timeStamp"].apply(lambda ts: ts.month)
ocurrences["Day of Week"]= ocurrences["timeStamp"].apply(lambda ts: ts.dayofweek)

# %%
ocurrences.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   lat          99492 non-null  float64
#  1   lng          99492 non-null  float64
#  2   desc         99492 non-null  object
#  3   zip          86637 non-null  float64
#  4   title        99492 non-null  object
#  5   timeStamp    99492 non-null  datetime64[ns]
#  6   twp          99449 non-null  object
#  7   addr         98973 non-null  object
#  8   e            99492 non-null  int64
#  9   Reason       99492 non-null  object
#  10  Hour         99492 non-null  int64
#  11  Month        99492 non-null  int64
#  12  Day of Week  99492 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 9.9+ MB

# %% [markdown]
# ** Observe como o dia da demana é um número inteiro de 0-6. Use o .map () com este dicionário para mapear os nomes das seqüências reais para o dia da semana: **
#
#     dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
# dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
# ocurrences["Day of Week"] = ocurrences["Day of Week"].map(dmap)
ocurrences.head(2)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
#
#                          addr  e Reason  Hour  Month Day of Week
# 0      REINDEER CT & DEAD END  1    EMS    17     12         Thu
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS    17     12         Thu

# %% [markdown]
# ** Agora use Seaborn para criar um countplot da coluna "Day of Week" com a tonalidade baseada na coluna Reason. **

# %%
sns.countplot(data=ocurrences,x='Day of Week', hue='Reason')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0)

# %% [markdown]
# ** Agora faça o mesmo para o mês: **

# %%
sns.countplot(data=ocurrences,x='Month', hue='Reason')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0)

# %% [markdown]
# ** Você notou algo estranho no Plot? **
#
# _____
#
# ** Você deve ter notado que estavam faltando alguns meses. Vejamos se podemos talvez preencher essa informação ao traçar as informações de outra forma, possivelmente um plot de linha simples que preencha os meses que faltam. Para fazer isso, precisamos trabalhar com pandas...

# %% [markdown]
# ** Agora, crie um objeto groupby chamado "byMonth", onde você agrupa o DataFrame pela coluna do mês e use o método count() para agregação. Use o método head() neste DataFrame retornado. **

# %%
byMonth = ocurrences.groupby("Month").count()
byMonth.head()
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      13205  13205  13205  11527  13205      13205  13203  13096  13205
# 2      11467  11467  11467   9930  11467      11467  11465  11396  11467
# 3      11101  11101  11101   9755  11101      11101  11092  11059  11101
# 4      11326  11326  11326   9895  11326      11326  11323  11283  11326
# 5      11423  11423  11423   9946  11423      11423  11420  11378  11423
#
#        Reason   Hour  Day of Week
# Month
# 1       13205  13205        13205
# 2       11467  11467        11467
# 3       11101  11101        11101
# 4       11326  11326        11326
# 5       11423  11423        11423

# %% [markdown]
# ** Agora crie um plot simples fora do Dataframe indicando a contagem de chamadas por mês. **

# %%
byMonth = ocurrences.groupby("Month").count()
byMonth['twp'].plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ** Agora veja se você pode usar o lmplot () do Seaborn para criar um modelo linear no número de chamadas por mês. Tenha em mente que talvez seja necessário resetar o índice em uma coluna. **

# %%
sns.lmplot(x='Month',y='twp',data=byMonth.reset_index())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 sns.lmplot(x='Month',data=byMonth.reset_index())
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\seaborn\regression.py:624, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     621     ax.update_datalim(xys, updatey=False)
#     622     ax.autoscale_view(scaley=False)
# --> 624 facets.map_dataframe(update_datalim, x=x, y=y)
#     626 # Draw the regression plot on each facet
#     627 regplot_kws = dict(
#     628     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
# ...

# %% [markdown]
# ** Crie uma nova coluna chamada 'Data' que contenha a data da coluna timeStamp. Você precisará usar .apply() junto com o método .date(). **

# %%
ocurrences['Date'] = ocurrences['timeStamp'].apply(lambda ts: ts.date())

# %% [markdown]
# ** Agora agrupe esta coluna Data com o groupby. Usando o count (), crie um gráfico de contagens de chamadas 911. **

# %%
ocurrences.groupby('Date')['twp'].count().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
title = 'EMS'

ocurrences[ocurrences['Reason']==title].groupby('Date').count()['twp'].plot()
plt.title(title)
plt.tight_layout()

# %% [markdown]
# ** Agora recrie esse plot, mas crie 3 plots separados com cada plot representando uma Razão para a chamada 911 **

# %%
title = 'Traffic'

ocurrences[ocurrences['Reason']==title].groupby('Date').count()['twp'].plot()
plt.title(title)
plt.tight_layout()

# %%
title = 'Fire'

ocurrences[ocurrences['Reason']==title].groupby('Date').count()['twp'].plot()
plt.title(title)
plt.tight_layout()

# %% [markdown]
# ____
# ** Agora vamos continuar a criar mapas de calor com seaborn e nossos dados. Em primeiro lugar, devemos reestruturar o quadro de dados para que as colunas se tornem horas e o Índice se torne o Dia da Semana. Há muitas maneiras de fazer isso, mas eu recomendaria tentar combinar groupby com o método [unstack](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html) . Consulte as soluções se você ficar preso nisso! **

# %%
# Mapa de calor: Dia da semana x horas, o agrupamento deve ser por dias da semana
plt.figure(figsize=(12,6))
sns.heatmap(ocurrences.groupby(by=['Day of Week', 'Hour'])['Reason'].count().unstack(),cmap='viridis')
# Out:
# <Axes: xlabel='Hour', ylabel='Day of Week'>

# %% [markdown]
# ** Agora crie um mapa de calor usando este DataFrame **

# %% [markdown]
# ** Agora crie um clustermap usando este DataFrame. **

# %%
# Mapa de calor: Dia da semana x horas, o agrupamento deve ser por dias da semana
plt.figure(figsize=(12,6))
sns.clustermap(ocurrences.groupby(by=['Day of Week', 'Hour'])['Reason'].count().unstack(),cmap='viridis')

# %% [markdown]
# ** Agora repita estes mesmos plots e operações para um DataFrame que mostra o mês como a coluna. **

# %%
# Mapa de calor: Dia da semana x horas, o agrupamento deve ser por dias da semana
plt.figure(figsize=(12,6))
sns.clustermap(ocurrences.groupby(by=['Month', 'Hour'])['Reason'].count().unstack(),cmap='viridis')

# %%
# Mapa de calor: Dia da semana x horas, o agrupamento deve ser por dias da semana
plt.figure(figsize=(12,6))
sns.heatmap(ocurrences.groupby(by=['Month', 'Hour'])['Reason'].count().unstack(),cmap='viridis')
# Out:
# <Axes: xlabel='Hour', ylabel='Month'>
